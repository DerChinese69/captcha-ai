# %% [markdown]
# # 5CharCNN Trainer

# %% [markdown]
# ## Imports

# %%
# --- Standard library ---
from pathlib import Path
import sys
import json
from datetime import datetime

# Locate repository root so that 'src' modules can be imported
REPO_ROOT = Path.cwd().resolve()
while REPO_ROOT != REPO_ROOT.parent and not (REPO_ROOT / "src").exists():
    REPO_ROOT = REPO_ROOT.parent

if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

print(f"Repository root found at: {REPO_ROOT}")

# --- Third-party ---
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

# --- Local imports ---
from src.dataset.dataloader import create_dataloaders
from src.models.FiveCharCNN import FiveCharCaptchaCNN
from src.training.engine import compute_metrics, unpack_batch, train_one_epoch, validate_one_epoch
# Out:
# Repository root found at: /Users/marc/Documents/VS-Code Projects/captcha-ai

# %% [markdown]
# ## Configure Settings

# %%
# =========================
# Config
# =========================

# Define path for saving runs and outputs
EXPERIMENTS_DIR = REPO_ROOT / "experiments"

# Create a new folder
RUN_NAME = f"test_run_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
RUN_DIR = EXPERIMENTS_DIR / RUN_NAME
RUN_DIR.mkdir(parents=True, exist_ok=True)

# Define paths for saving models, history, and plots
BEST_MODEL_PATH = RUN_DIR / "best_model.pt"
LAST_MODEL_PATH = RUN_DIR / "last_model.pt"
HISTORY_PATH = RUN_DIR / "training_history.json"
CONFIG_PATH = RUN_DIR / "config.json"
CURVES_PATH = RUN_DIR / "training_curves.png"


# =========================
# Core task config
# =========================

NUM_CHAR_CLASSES = 51
LABEL_LENGTH = 5


# =========================
# Training config
# =========================

BATCH_SIZE = 64
NUM_EPOCHS = 100
LEARNING_RATE = 3e-4


# =========================
# Dataset split config
# =========================

TRAIN_RATIO = 0.7
VAL_RATIO = 0.15
TEST_RATIO = 0.15

RANDOM_SEED = 69
TRAINING = True
SHUFFLE_TRAIN = True

NUM_WORKERS = 0
PIN_MEMORY = False
DROP_LAST = False

SUBSET_FRACTION = 0.2
RETURN_FILENAMES = False


# =========================
# Debug & Performance config
# =========================

SAVE_PLOTS = True
PRINT_BATCH_SHAPES = True


# =========================
# Device config
# =========================

if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
elif torch.backends.mps.is_available():
    DEVICE = torch.device("mps")
else:
    DEVICE = torch.device("cpu")

print(f"Using device: {DEVICE}")
print(f"Run directory: {RUN_DIR}")
# Out:
# Using device: mps
# Run directory: /Users/marc/Documents/VS-Code Projects/captcha-ai/experiments/test_run_20260317_000652

# %% [markdown]
# ## Save Run Configurations

# %%
CONFIG = {
    "num_char_classes": NUM_CHAR_CLASSES,
    "label_length": LABEL_LENGTH,
    
    "batch_size": BATCH_SIZE,
    "num_epochs": NUM_EPOCHS,
    "learning_rate": LEARNING_RATE,
    
    "train_ratio": TRAIN_RATIO,
    "val_ratio": VAL_RATIO,
    "test_ratio": TEST_RATIO,
    "random_seed": RANDOM_SEED,
    
    "shuffle_train": SHUFFLE_TRAIN,
    "num_workers": NUM_WORKERS,
    "pin_memory": PIN_MEMORY,
    "drop_last": DROP_LAST,
    
    "subset_fraction": SUBSET_FRACTION,
    "return_filenames": RETURN_FILENAMES,

    "device": str(DEVICE),
}


with open(CONFIG_PATH, "w") as f:
    json.dump(CONFIG, f, indent=4)

# %% [markdown]
# ## Create Data loaders

# %%
# =========================
# Create dataloaders
# =========================

# Create train/validation/test dataloaders and character mappings
train_loader, val_loader, test_loader, char_to_idx, idx_to_char = create_dataloaders(
    batch_size=BATCH_SIZE,
    train_ratio=TRAIN_RATIO,
    val_ratio=VAL_RATIO,
    test_ratio=TEST_RATIO,
    random_seed=RANDOM_SEED,
    training=TRAINING,
    shuffle_train=SHUFFLE_TRAIN,
    num_workers=NUM_WORKERS,
    pin_memory=PIN_MEMORY,
    drop_last=DROP_LAST,
    subset_fraction=SUBSET_FRACTION,
    return_filenames=RETURN_FILENAMES,
)
print("Loaders created successfully.")
# Out:
# Loaders created successfully.

# %% [markdown]
# ## Initialize model

# %%
# =========================
# Initialize model + loss function + optimizer
# =========================

#Initialize model and move to selecteddevice
model = FiveCharCaptchaCNN(
    num_char_classes=NUM_CHAR_CLASSES,
    label_length=LABEL_LENGTH
).to(DEVICE)
print("Model initialized.")

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
print("Optimizer and loss function initialized.")

#print(model)
# Out:
# Model initialized.
# Optimizer and loss function initialized.

# %% [markdown]
# ## Define Optimizer and create History

# %%
# =========================
# Create history
# =========================
history = {
    "train_loss": [],
    "val_loss": [],
    "train_char_acc": [],
    "val_char_acc": [],
    "train_seq_acc": [],
    "val_seq_acc": [],
    "val_pos_acc_0": [],
    "val_pos_acc_1": [],
    "val_pos_acc_2": [],
    "val_pos_acc_3": [],
    "val_pos_acc_4": [],
}

print("History initialized.")
# Out:
# History initialized.

# %% [markdown]
# ## Training Loop

# %%
# =========================
# Full training loop
# =========================

best_val_seq_acc = -1.0

for epoch in range(NUM_EPOCHS):
    train_loss, train_char_acc, train_seq_acc = train_one_epoch(
    model=model,
    loader=train_loader,
    optimizer=optimizer,
    criterion=criterion,
    device=DEVICE,
    num_char_classes=NUM_CHAR_CLASSES,
)

    val_loss, val_char_acc, val_seq_acc, val_pos_accs = validate_one_epoch(
    model=model,
    loader=val_loader,
    criterion=criterion,
    device=DEVICE,
    num_char_classes=NUM_CHAR_CLASSES,
    label_length=LABEL_LENGTH,
)

    # Save metrics
    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_char_acc"].append(train_char_acc)
    history["val_char_acc"].append(val_char_acc)
    history["train_seq_acc"].append(train_seq_acc)
    history["val_seq_acc"].append(val_seq_acc)

    for i in range(LABEL_LENGTH):
        history[f"val_pos_acc_{i}"].append(val_pos_accs[i])

    # Epoch panel
    print(f"\nEpoch [{epoch+1}/{NUM_EPOCHS}]")
    print(f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
    print(f"Train Char Acc: {train_char_acc:.4f} | Val Char Acc: {val_char_acc:.4f}")
    print(f"Train Seq Acc:  {train_seq_acc:.4f} | Val Seq Acc:  {val_seq_acc:.4f}")
    print("Val Pos Accs:", [f"{acc:.4f}" for acc in val_pos_accs])

    # Save best model
    if val_seq_acc > best_val_seq_acc:
        best_val_seq_acc = val_seq_acc
        torch.save(model.state_dict(), BEST_MODEL_PATH)
        print(f"New best model saved to: {BEST_MODEL_PATH}")

# Save last model
torch.save(model.state_dict(), LAST_MODEL_PATH)
print(f"\nLast model saved to: {LAST_MODEL_PATH}")

# =========================
# Save training history
# =========================

with open(HISTORY_PATH, "w") as f:
    json.dump(history, f, indent=4)

print(f"Training history saved to: {HISTORY_PATH}")
# Out:
# Epoch [1/100]
# Train Loss: 3.9850 | Val Loss: 3.9346
# Train Char Acc: 0.0165 | Val Char Acc: 0.0400
# Train Seq Acc:  0.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0333', '0.0667', '0.0333', '0.0333']
# New best model saved to: /Users/marc/Documents/VS-Code Projects/captcha-ai/experiments/test_run_20260317_000652/best_model.pt
#
# Epoch [2/100]
# Train Loss: 3.8383 | Val Loss: 3.9431
# Train Char Acc: 0.0394 | Val Char Acc: 0.0233
# Train Seq Acc:  0.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0333', '0.0167', '0.0333', '0.0333']
#
# Epoch [3/100]
# Train Loss: 3.7315 | Val Loss: 3.9581
# Train Char Acc: 0.0838 | Val Char Acc: 0.0233
# Train Seq Acc:  0.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0333', '0.0167', '0.0333', '0.0333']
#
# Epoch [4/100]
# Train Loss: 3.6475 | Val Loss: 3.9785
# Train Char Acc: 0.0890 | Val Char Acc: 0.0200
# Train Seq Acc:  0.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0333', '0.0167', '0.0333', '0.0167']
#
# Epoch [5/100]
# Train Loss: 3.4966 | Val Loss: 3.9915
# Train Char Acc: 0.1346 | Val Char Acc: 0.0133
# Train Seq Acc:  0.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0000', '0.0167', '0.0333', '0.0167']
#
# Epoch [6/100]
# Train Loss: 3.3633 | Val Loss: 4.0042
# Train Char Acc: 0.1894 | Val Char Acc: 0.0200
# Train Seq Acc:  0.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0000', '0.0333', '0.0333', '0.0333']
#
# Epoch [7/100]
# Train Loss: 3.2333 | Val Loss: 4.0420
# Train Char Acc: 0.2146 | Val Char Acc: 0.0200
# Train Seq Acc:  0.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0167', '0.0167', '0.0333', '0.0333']
#
# Epoch [8/100]
# Train Loss: 3.1139 | Val Loss: 4.0500
# Train Char Acc: 0.2625 | Val Char Acc: 0.0167
# Train Seq Acc:  0.0063 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0167', '0.0167', '0.0167', '0.0333']
#
# Epoch [9/100]
# Train Loss: 2.9461 | Val Loss: 4.0549
# Train Char Acc: 0.3548 | Val Char Acc: 0.0367
# Train Seq Acc:  0.0333 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0333', '0.0667', '0.0500', '0.0333']
#
# Epoch [10/100]
# Train Loss: 2.8001 | Val Loss: 4.1064
# Train Char Acc: 0.4150 | Val Char Acc: 0.0333
# Train Seq Acc:  0.0437 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0500', '0.0500', '0.0333', '0.0333']
#
# Epoch [11/100]
# Train Loss: 2.6140 | Val Loss: 4.1269
# Train Char Acc: 0.4512 | Val Char Acc: 0.0433
# Train Seq Acc:  0.0563 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0333', '0.0500', '0.0667', '0.0667']
#
# Epoch [12/100]
# Train Loss: 2.4802 | Val Loss: 4.1195
# Train Char Acc: 0.5204 | Val Char Acc: 0.0367
# Train Seq Acc:  0.1083 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0333', '0.0167', '0.0833']
#
# Epoch [13/100]
# Train Loss: 2.2881 | Val Loss: 4.1426
# Train Char Acc: 0.5892 | Val Char Acc: 0.0333
# Train Seq Acc:  0.1604 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0333', '0.0500', '0.0333', '0.0500']
#
# Epoch [14/100]
# Train Loss: 2.1466 | Val Loss: 4.1696
# Train Char Acc: 0.6523 | Val Char Acc: 0.0300
# Train Seq Acc:  0.2208 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0000', '0.0500', '0.0333', '0.0500']
#
# Epoch [15/100]
# Train Loss: 1.9798 | Val Loss: 4.1494
# Train Char Acc: 0.7027 | Val Char Acc: 0.0267
# Train Seq Acc:  0.2625 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0167', '0.0500', '0.0333', '0.0333']
#
# Epoch [16/100]
# Train Loss: 1.8123 | Val Loss: 4.1853
# Train Char Acc: 0.7288 | Val Char Acc: 0.0233
# Train Seq Acc:  0.3115 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0167', '0.0167', '0.0333']
#
# Epoch [17/100]
# Train Loss: 1.6883 | Val Loss: 4.2294
# Train Char Acc: 0.7663 | Val Char Acc: 0.0333
# Train Seq Acc:  0.3812 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0167', '0.0333', '0.0167', '0.0667']
#
# Epoch [18/100]
# Train Loss: 1.5747 | Val Loss: 4.1773
# Train Char Acc: 0.7663 | Val Char Acc: 0.0300
# Train Seq Acc:  0.3802 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0333', '0.0333', '0.0500']
#
# Epoch [19/100]
# Train Loss: 1.4116 | Val Loss: 4.1941
# Train Char Acc: 0.8231 | Val Char Acc: 0.0200
# Train Seq Acc:  0.4823 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0000', '0.0500', '0.0333', '0.0167']
#
# Epoch [20/100]
# Train Loss: 1.3143 | Val Loss: 4.2598
# Train Char Acc: 0.8402 | Val Char Acc: 0.0233
# Train Seq Acc:  0.5260 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0167', '0.0333', '0.0333']
#
# Epoch [21/100]
# Train Loss: 1.2025 | Val Loss: 4.2239
# Train Char Acc: 0.8698 | Val Char Acc: 0.0233
# Train Seq Acc:  0.5635 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0000', '0.0333', '0.0167', '0.0333']
#
# Epoch [22/100]
# Train Loss: 1.0756 | Val Loss: 4.2130
# Train Char Acc: 0.8888 | Val Char Acc: 0.0267
# Train Seq Acc:  0.6115 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0500', '0.0333', '0.0167']
#
# Epoch [23/100]
# Train Loss: 1.0046 | Val Loss: 4.2689
# Train Char Acc: 0.8958 | Val Char Acc: 0.0167
# Train Seq Acc:  0.6833 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0167', '0.0167', '0.0333', '0.0167']
#
# Epoch [24/100]
# Train Loss: 0.8444 | Val Loss: 4.2716
# Train Char Acc: 0.9238 | Val Char Acc: 0.0267
# Train Seq Acc:  0.7333 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0167', '0.0167', '0.0500', '0.0167']
#
# Epoch [25/100]
# Train Loss: 0.7805 | Val Loss: 4.2783
# Train Char Acc: 0.9323 | Val Char Acc: 0.0233
# Train Seq Acc:  0.7688 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0500', '0.0167', '0.0167']
#
# Epoch [26/100]
# Train Loss: 0.6757 | Val Loss: 4.2977
# Train Char Acc: 0.9402 | Val Char Acc: 0.0333
# Train Seq Acc:  0.7604 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0333', '0.0500', '0.0333', '0.0167']
#
# Epoch [27/100]
# Train Loss: 0.6443 | Val Loss: 4.2999
# Train Char Acc: 0.9492 | Val Char Acc: 0.0267
# Train Seq Acc:  0.8042 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0167', '0.0500', '0.0167']
#
# Epoch [28/100]
# Train Loss: 0.5855 | Val Loss: 4.2875
# Train Char Acc: 0.9552 | Val Char Acc: 0.0267
# Train Seq Acc:  0.8323 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0167', '0.0167', '0.0667', '0.0333']
#
# Epoch [29/100]
# Train Loss: 0.5211 | Val Loss: 4.2816
# Train Char Acc: 0.9598 | Val Char Acc: 0.0267
# Train Seq Acc:  0.8427 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0167', '0.0167', '0.0500']
#
# Epoch [30/100]
# Train Loss: 0.4625 | Val Loss: 4.3142
# Train Char Acc: 0.9702 | Val Char Acc: 0.0200
# Train Seq Acc:  0.8771 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0167', '0.0167', '0.0167']
#
# Epoch [31/100]
# Train Loss: 0.4332 | Val Loss: 4.2993
# Train Char Acc: 0.9710 | Val Char Acc: 0.0267
# Train Seq Acc:  0.8698 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0667', '0.0167', '0.0167']
#
# Epoch [32/100]
# Train Loss: 0.3793 | Val Loss: 4.3716
# Train Char Acc: 0.9827 | Val Char Acc: 0.0333
# Train Seq Acc:  0.9229 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0333', '0.0500', '0.0167', '0.0667']
#
# Epoch [33/100]
# Train Loss: 0.3591 | Val Loss: 4.3748
# Train Char Acc: 0.9844 | Val Char Acc: 0.0367
# Train Seq Acc:  0.9333 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0333', '0.0333', '0.0333', '0.0500']
#
# Epoch [34/100]
# Train Loss: 0.3046 | Val Loss: 4.4080
# Train Char Acc: 0.9881 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9437 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0333', '0.0500', '0.0167']
#
# Epoch [35/100]
# Train Loss: 0.2877 | Val Loss: 4.3990
# Train Char Acc: 0.9879 | Val Char Acc: 0.0333
# Train Seq Acc:  0.9458 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0167', '0.0667', '0.0333', '0.0167']
#
# Epoch [36/100]
# Train Loss: 0.2762 | Val Loss: 4.3993
# Train Char Acc: 0.9885 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9427 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0333', '0.0167', '0.0500']
#
# Epoch [37/100]
# Train Loss: 0.2339 | Val Loss: 4.4262
# Train Char Acc: 0.9896 | Val Char Acc: 0.0267
# Train Seq Acc:  0.9510 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0333', '0.0167', '0.0333']
#
# Epoch [38/100]
# Train Loss: 0.2350 | Val Loss: 4.4329
# Train Char Acc: 0.9913 | Val Char Acc: 0.0233
# Train Seq Acc:  0.9563 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0167', '0.0333', '0.0333']
#
# Epoch [39/100]
# Train Loss: 0.2036 | Val Loss: 4.4126
# Train Char Acc: 0.9927 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9635 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0500', '0.0333', '0.0167', '0.0167', '0.0333']
#
# Epoch [40/100]
# Train Loss: 0.1900 | Val Loss: 4.4282
# Train Char Acc: 0.9975 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9875 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0333', '0.0333', '0.0333', '0.0167']
#
# Epoch [41/100]
# Train Loss: 0.1941 | Val Loss: 4.4807
# Train Char Acc: 0.9948 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9740 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0333', '0.0667', '0.0333', '0.0167']
#
# Epoch [42/100]
# Train Loss: 0.1653 | Val Loss: 4.4876
# Train Char Acc: 0.9913 | Val Char Acc: 0.0333
# Train Seq Acc:  0.9656 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0500', '0.0500', '0.0333', '0.0167']
#
# Epoch [43/100]
# Train Loss: 0.1626 | Val Loss: 4.5021
# Train Char Acc: 0.9917 | Val Char Acc: 0.0333
# Train Seq Acc:  0.9583 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0500', '0.0333', '0.0333']
#
# Epoch [44/100]
# Train Loss: 0.1489 | Val Loss: 4.4752
# Train Char Acc: 0.9933 | Val Char Acc: 0.0333
# Train Seq Acc:  0.9667 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0333', '0.0333', '0.0333', '0.0333']
#
# Epoch [45/100]
# Train Loss: 0.1288 | Val Loss: 4.5063
# Train Char Acc: 0.9963 | Val Char Acc: 0.0200
# Train Seq Acc:  0.9812 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0167', '0.0333', '0.0167']
#
# Epoch [46/100]
# Train Loss: 0.1182 | Val Loss: 4.4688
# Train Char Acc: 0.9971 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9854 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0333', '0.0333', '0.0333']
#
# Epoch [47/100]
# Train Loss: 0.1149 | Val Loss: 4.5678
# Train Char Acc: 0.9975 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9875 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0667', '0.0167', '0.0333', '0.0167']
#
# Epoch [48/100]
# Train Loss: 0.1270 | Val Loss: 4.4954
# Train Char Acc: 0.9950 | Val Char Acc: 0.0267
# Train Seq Acc:  0.9750 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0333', '0.0333', '0.0167']
#
# Epoch [49/100]
# Train Loss: 0.1138 | Val Loss: 4.5247
# Train Char Acc: 0.9952 | Val Char Acc: 0.0233
# Train Seq Acc:  0.9760 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0167', '0.0333', '0.0167', '0.0167']
#
# Epoch [50/100]
# Train Loss: 0.1030 | Val Loss: 4.5202
# Train Char Acc: 0.9981 | Val Char Acc: 0.0367
# Train Seq Acc:  0.9906 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0333', '0.0500', '0.0500', '0.0167']
#
# Epoch [51/100]
# Train Loss: 0.1062 | Val Loss: 4.5043
# Train Char Acc: 0.9971 | Val Char Acc: 0.0233
# Train Seq Acc:  0.9854 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0333', '0.0333', '0.0167']
#
# Epoch [52/100]
# Train Loss: 0.0892 | Val Loss: 4.6144
# Train Char Acc: 0.9946 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9729 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0667', '0.0333', '0.0167']
#
# Epoch [53/100]
# Train Loss: 0.0877 | Val Loss: 4.5623
# Train Char Acc: 0.9994 | Val Char Acc: 0.0233
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0333', '0.0167', '0.0333']
#
# Epoch [54/100]
# Train Loss: 0.0884 | Val Loss: 4.4986
# Train Char Acc: 0.9946 | Val Char Acc: 0.0267
# Train Seq Acc:  0.9729 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0333', '0.0333', '0.0167', '0.0167']
#
# Epoch [55/100]
# Train Loss: 0.0875 | Val Loss: 4.5791
# Train Char Acc: 0.9994 | Val Char Acc: 0.0333
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0500', '0.0167', '0.0333', '0.0333']
#
# Epoch [56/100]
# Train Loss: 0.0853 | Val Loss: 4.5711
# Train Char Acc: 0.9958 | Val Char Acc: 0.0367
# Train Seq Acc:  0.9823 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0500', '0.0333', '0.0500', '0.0167']
#
# Epoch [57/100]
# Train Loss: 0.0851 | Val Loss: 4.5267
# Train Char Acc: 0.9975 | Val Char Acc: 0.0267
# Train Seq Acc:  0.9875 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0333', '0.0333', '0.0167']
#
# Epoch [58/100]
# Train Loss: 0.0645 | Val Loss: 4.5894
# Train Char Acc: 0.9994 | Val Char Acc: 0.0267
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0333', '0.0333', '0.0167']
#
# Epoch [59/100]
# Train Loss: 0.0745 | Val Loss: 4.5971
# Train Char Acc: 0.9960 | Val Char Acc: 0.0267
# Train Seq Acc:  0.9802 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0167', '0.0333', '0.0333', '0.0167']
#
# Epoch [60/100]
# Train Loss: 0.0799 | Val Loss: 4.5953
# Train Char Acc: 0.9971 | Val Char Acc: 0.0333
# Train Seq Acc:  0.9854 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0333', '0.0500', '0.0333', '0.0167']
#
# Epoch [61/100]
# Train Loss: 0.0662 | Val Loss: 4.6216
# Train Char Acc: 0.9958 | Val Char Acc: 0.0333
# Train Seq Acc:  0.9792 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0333', '0.0333', '0.0500', '0.0167']
#
# Epoch [62/100]
# Train Loss: 0.0641 | Val Loss: 4.6011
# Train Char Acc: 0.9971 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9854 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0333', '0.0333', '0.0333', '0.0167']
#
# Epoch [63/100]
# Train Loss: 0.0754 | Val Loss: 4.5630
# Train Char Acc: 0.9963 | Val Char Acc: 0.0233
# Train Seq Acc:  0.9812 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0333', '0.0167', '0.0167']
#
# Epoch [64/100]
# Train Loss: 0.0656 | Val Loss: 4.6316
# Train Char Acc: 0.9994 | Val Char Acc: 0.0233
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0333', '0.0333', '0.0167']
#
# Epoch [65/100]
# Train Loss: 0.0602 | Val Loss: 4.5474
# Train Char Acc: 0.9958 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9792 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0500', '0.0167', '0.0333', '0.0333']
#
# Epoch [66/100]
# Train Loss: 0.0523 | Val Loss: 4.6379
# Train Char Acc: 0.9988 | Val Char Acc: 0.0233
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0333', '0.0333', '0.0333', '0.0167']
#
# Epoch [67/100]
# Train Loss: 0.0599 | Val Loss: 4.6578
# Train Char Acc: 1.0000 | Val Char Acc: 0.0233
# Train Seq Acc:  1.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0167', '0.0167', '0.0667', '0.0167']
#
# Epoch [68/100]
# Train Loss: 0.0589 | Val Loss: 4.6922
# Train Char Acc: 0.9975 | Val Char Acc: 0.0233
# Train Seq Acc:  0.9875 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0167', '0.0167', '0.0667', '0.0167']
#
# Epoch [69/100]
# Train Loss: 0.0559 | Val Loss: 4.6980
# Train Char Acc: 0.9994 | Val Char Acc: 0.0167
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0167', '0.0167', '0.0333', '0.0167']
#
# Epoch [70/100]
# Train Loss: 0.0433 | Val Loss: 4.6828
# Train Char Acc: 1.0000 | Val Char Acc: 0.0267
# Train Seq Acc:  1.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0167', '0.0500', '0.0167']
#
# Epoch [71/100]
# Train Loss: 0.0461 | Val Loss: 4.6254
# Train Char Acc: 0.9983 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9917 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0333', '0.0167', '0.0333', '0.0333']
#
# Epoch [72/100]
# Train Loss: 0.0430 | Val Loss: 4.6416
# Train Char Acc: 0.9977 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9885 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0500', '0.0167', '0.0333', '0.0333']
#
# Epoch [73/100]
# Train Loss: 0.0360 | Val Loss: 4.6929
# Train Char Acc: 0.9994 | Val Char Acc: 0.0200
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0167', '0.0167', '0.0500', '0.0167']
#
# Epoch [74/100]
# Train Loss: 0.0383 | Val Loss: 4.6120
# Train Char Acc: 0.9981 | Val Char Acc: 0.0233
# Train Seq Acc:  0.9906 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0333', '0.0333', '0.0167']
#
# Epoch [75/100]
# Train Loss: 0.0389 | Val Loss: 4.7009
# Train Char Acc: 0.9987 | Val Char Acc: 0.0200
# Train Seq Acc:  0.9938 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0167', '0.0333', '0.0167']
#
# Epoch [76/100]
# Train Loss: 0.0321 | Val Loss: 4.7477
# Train Char Acc: 0.9994 | Val Char Acc: 0.0267
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0333', '0.0333', '0.0167']
#
# Epoch [77/100]
# Train Loss: 0.0486 | Val Loss: 4.6611
# Train Char Acc: 0.9967 | Val Char Acc: 0.0233
# Train Seq Acc:  0.9833 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0333', '0.0333', '0.0167']
#
# Epoch [78/100]
# Train Loss: 0.0361 | Val Loss: 4.6648
# Train Char Acc: 0.9987 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9938 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0167', '0.0333', '0.0500', '0.0167']
#
# Epoch [79/100]
# Train Loss: 0.0365 | Val Loss: 4.6677
# Train Char Acc: 1.0000 | Val Char Acc: 0.0367
# Train Seq Acc:  1.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0333', '0.0500', '0.0500']
#
# Epoch [80/100]
# Train Loss: 0.0411 | Val Loss: 4.7279
# Train Char Acc: 0.9987 | Val Char Acc: 0.0333
# Train Seq Acc:  0.9938 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0500', '0.0333', '0.0333']
#
# Epoch [81/100]
# Train Loss: 0.0330 | Val Loss: 4.7694
# Train Char Acc: 0.9975 | Val Char Acc: 0.0267
# Train Seq Acc:  0.9875 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0500', '0.0167', '0.0167']
#
# Epoch [82/100]
# Train Loss: 0.0389 | Val Loss: 4.7246
# Train Char Acc: 0.9994 | Val Char Acc: 0.0200
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0167', '0.0167', '0.0167']
#
# Epoch [83/100]
# Train Loss: 0.0360 | Val Loss: 4.6903
# Train Char Acc: 0.9975 | Val Char Acc: 0.0267
# Train Seq Acc:  0.9875 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0333', '0.0333', '0.0167']
#
# Epoch [84/100]
# Train Loss: 0.0301 | Val Loss: 4.7659
# Train Char Acc: 1.0000 | Val Char Acc: 0.0300
# Train Seq Acc:  1.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0167', '0.0333', '0.0500', '0.0167']
#
# Epoch [85/100]
# Train Loss: 0.0311 | Val Loss: 4.7910
# Train Char Acc: 0.9981 | Val Char Acc: 0.0233
# Train Seq Acc:  0.9906 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0167', '0.0167', '0.0333', '0.0167']
#
# Epoch [86/100]
# Train Loss: 0.0357 | Val Loss: 4.7114
# Train Char Acc: 1.0000 | Val Char Acc: 0.0233
# Train Seq Acc:  1.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0333', '0.0333', '0.0167']
#
# Epoch [87/100]
# Train Loss: 0.0377 | Val Loss: 4.7834
# Train Char Acc: 1.0000 | Val Char Acc: 0.0300
# Train Seq Acc:  1.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0000', '0.0333', '0.0667', '0.0333', '0.0167']
#
# Epoch [88/100]
# Train Loss: 0.0298 | Val Loss: 4.7082
# Train Char Acc: 0.9994 | Val Char Acc: 0.0333
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0333', '0.0500', '0.0333']
#
# Epoch [89/100]
# Train Loss: 0.0294 | Val Loss: 4.6673
# Train Char Acc: 0.9994 | Val Char Acc: 0.0333
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0333', '0.0333', '0.0333', '0.0333']
#
# Epoch [90/100]
# Train Loss: 0.0314 | Val Loss: 4.7433
# Train Char Acc: 0.9994 | Val Char Acc: 0.0267
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0500', '0.0333', '0.0167']
#
# Epoch [91/100]
# Train Loss: 0.0229 | Val Loss: 4.7681
# Train Char Acc: 1.0000 | Val Char Acc: 0.0233
# Train Seq Acc:  1.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0333', '0.0333', '0.0167']
#
# Epoch [92/100]
# Train Loss: 0.0215 | Val Loss: 4.7690
# Train Char Acc: 1.0000 | Val Char Acc: 0.0267
# Train Seq Acc:  1.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0500', '0.0333', '0.0167', '0.0167', '0.0167']
#
# Epoch [93/100]
# Train Loss: 0.0271 | Val Loss: 4.7691
# Train Char Acc: 0.9977 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9885 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0500', '0.0167', '0.0333', '0.0167', '0.0333']
#
# Epoch [94/100]
# Train Loss: 0.0256 | Val Loss: 4.7749
# Train Char Acc: 1.0000 | Val Char Acc: 0.0333
# Train Seq Acc:  1.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0500', '0.0500', '0.0333']
#
# Epoch [95/100]
# Train Loss: 0.0270 | Val Loss: 4.7777
# Train Char Acc: 0.9994 | Val Char Acc: 0.0333
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0167', '0.0500', '0.0500', '0.0167']
#
# Epoch [96/100]
# Train Loss: 0.0220 | Val Loss: 4.8114
# Train Char Acc: 1.0000 | Val Char Acc: 0.0200
# Train Seq Acc:  1.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0167', '0.0167', '0.0333', '0.0167']
#
# Epoch [97/100]
# Train Loss: 0.0262 | Val Loss: 4.8299
# Train Char Acc: 0.9994 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0167', '0.0333', '0.0500', '0.0333', '0.0167']
#
# Epoch [98/100]
# Train Loss: 0.0242 | Val Loss: 4.7569
# Train Char Acc: 0.9994 | Val Char Acc: 0.0267
# Train Seq Acc:  0.9969 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0333', '0.0167', '0.0333', '0.0167', '0.0333']
#
# Epoch [99/100]
# Train Loss: 0.0240 | Val Loss: 4.7744
# Train Char Acc: 1.0000 | Val Char Acc: 0.0267
# Train Seq Acc:  1.0000 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0500', '0.0167', '0.0333', '0.0167', '0.0167']
#
# Epoch [100/100]
# Train Loss: 0.0220 | Val Loss: 4.7720
# Train Char Acc: 0.9987 | Val Char Acc: 0.0300
# Train Seq Acc:  0.9938 | Val Seq Acc:  0.0000
# Val Pos Accs: ['0.0500', '0.0167', '0.0333', '0.0167', '0.0333']
#
# Last model saved to: /Users/marc/Documents/VS-Code Projects/captcha-ai/experiments/test_run_20260317_000652/last_model.pt
# Training history saved to: /Users/marc/Documents/VS-Code Projects/captcha-ai/experiments/test_run_20260317_000652/training_history.json

# %% [markdown]
# ## Plot Curves

# %%
# =========================
# Plot training curves
# =========================

epochs = range(1, NUM_EPOCHS + 1)

plt.figure(figsize=(8, 5))
plt.plot(epochs, history["train_loss"], label="Train Loss")
plt.plot(epochs, history["val_loss"], label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.grid(True)
if SAVE_PLOTS:
    plt.savefig(CURVES_PATH.with_name("loss_" + CURVES_PATH.name), bbox_inches="tight")
plt.show()


plt.figure(figsize=(8, 5))
plt.plot(epochs, history["train_char_acc"], label="Train Char Acc")
plt.plot(epochs, history["val_char_acc"], label="Val Char Acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training and Validation Character Accuracy")
plt.legend()
plt.grid(True)
if SAVE_PLOTS:
    plt.savefig(CURVES_PATH.with_name("char_acc_" + CURVES_PATH.name), bbox_inches="tight")
plt.show()


plt.figure(figsize=(8, 5))
plt.plot(epochs, history["train_seq_acc"], label="Train Seq Acc")
plt.plot(epochs, history["val_seq_acc"], label="Val Seq Acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training and Validation Sequence Accuracy")
plt.legend()
plt.grid(True)
if SAVE_PLOTS:
    plt.savefig(CURVES_PATH.with_name("seq_acc_" + CURVES_PATH.name), bbox_inches="tight")
plt.show()


plt.figure(figsize=(8, 5))
for i in range(LABEL_LENGTH):
    plt.plot(epochs, history[f"val_pos_acc_{i}"], label=f"Val Pos {i}")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Per-Position Accuracy")
plt.legend()
plt.grid(True)
if SAVE_PLOTS:
    plt.savefig(CURVES_PATH.with_name("val_pos_acc_" + CURVES_PATH.name), bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Inspect Predictions

# %%
# =========================
# Inspect validation predictions
# =========================

model.eval()

num_examples_to_show = 5

with torch.no_grad():
    batch = next(iter(val_loader))
    images, labels, filenames = unpack_batch(batch)

    images = images.to(DEVICE)
    labels = labels.to(DEVICE)

    outputs = model(images)
    preds = outputs.argmax(dim=-1)

labels = labels.cpu()
preds = preds.cpu()

print("\nValidation predictions preview\n")

for i in range(min(num_examples_to_show, images.size(0))):
    true_string = "".join(idx_to_char[int(x)] for x in labels[i])
    pred_string = "".join(idx_to_char[int(x)] for x in preds[i])

    print(f"Example {i+1}")
    print(f"True: {true_string}")
    print(f"Pred: {pred_string}")

    if filenames is not None:
        print(f"File: {filenames[i]}")

    print("-" * 30)
# Out:
# Validation predictions preview
#
# Example 1
# True: mVJdA
# Pred: KGxGu
# ------------------------------
# Example 2
# True: eYtYN
# Pred: TeeYX
# ------------------------------
# Example 3
# True: h4QmG
# Pred: CBRut
# ------------------------------
# Example 4
# True: ta4DJ
# Pred: tELR8
# ------------------------------
# Example 5
# True: 8htdf
# Pred: LNJ8h
# ------------------------------

# %% [markdown]
# ## (Optional) manual visual inspection

# %%
# =========================
# Show validation images with true/pred labels
# =========================

num_images_to_show = 5

for i in range(min(num_images_to_show, images.size(0))):
    img_np = images[i].detach().cpu().squeeze().numpy()
    true_string = "".join(idx_to_char[int(x)] for x in labels[i])
    pred_string = "".join(idx_to_char[int(x)] for x in preds[i])

    plt.figure(figsize=(4, 2))
    plt.imshow(img_np, cmap="gray")
    plt.title(f"True: {true_string} | Pred: {pred_string}")
    plt.axis("off")
    plt.show()
