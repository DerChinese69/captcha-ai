# %%
pip install captcha
# Out:
# Collecting captcha
#   Downloading captcha-0.7.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: Pillow in /Users/marc/miniconda3/lib/python3.13/site-packages (from captcha) (12.1.1)
# Downloading captcha-0.7.1-py3-none-any.whl (147 kB)
# Installing collected packages: captcha
# Successfully installed captcha-0.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from captcha.image import ImageCaptcha

image = ImageCaptcha(fonts=['/System/Library/Fonts/Helvetica.ttc', '/System/Library/Fonts/ArialHB.ttf'])

data = image.generate('1234')

image.write('1234', 'out.png')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[12], line 5
#       1 from captcha.image import ImageCaptcha
#       3 image = ImageCaptcha(fonts=['/System/Library/Fonts/Helvetica.ttc', '/System/Library/Fonts/ArialHB.ttf'])
# ----> 5 data = image.generate('1234')
#       7 image.write('1234', 'out.png')
#
# File ~/miniconda3/lib/python3.13/site-packages/captcha/image.py:219, in ImageCaptcha.generate(self, chars, format, bg_color, fg_color)
#     209 def generate(self, chars: str, format: str = 'png',
#     210              bg_color: ColorTuple | None = None,
#     211              fg_color: ColorTuple | None = None) -> BytesIO:
#     212     """Generate an Image Captcha of the given characters.
#     213
#     214     :param chars: text to be generated.
#    (...)    217     :param fg_color: foreground color of the text in rgba format (r,g,b,a).
#     218     """
# --> 219     im = self.generate_image(chars, bg_color=bg_color, fg_color=fg_color)
#     220     out = BytesIO()
#     221     im.save(out, format=format)
#
# File ~/miniconda3/lib/python3.13/site-packages/captcha/image.py:203, in ImageCaptcha.generate_image(self, chars, bg_color, fg_color)
#     200 random_fg_color = random_color(10, 200, secrets.randbelow(36) + 220)
#     201 color: ColorTuple = fg_color if fg_color else random_fg_color
# --> 203 im = self.create_captcha_image(chars, color, background)
#     204 self.create_noise_dots(im, color)
#     205 self.create_noise_curve(im, color)
#
# File ~/miniconda3/lib/python3.13/site-packages/captcha/image.py:168, in ImageCaptcha.create_captcha_image(self, chars, color, background)
#     166     if secrets.randbits(32) / (2**32) > self.word_space_probability:
#     167         images.append(self._draw_character(" ", draw, color))
# --> 168     images.append(self._draw_character(c, draw, color))
#     170 text_width = sum([im.size[0] for im in images])
#     172 width = max(text_width, self._width)
#
# File ~/miniconda3/lib/python3.13/site-packages/captcha/image.py:113, in ImageCaptcha._draw_character(self, c, draw, color)
#     108 def _draw_character(
#     109         self,
#     110         c: str,
#     111         draw: ImageDraw,
#     112         color: ColorTuple) -> Image:
# --> 113     font = secrets.choice(self.truefonts)
#     114     _, _, w, h = draw.multiline_textbbox((1, 1), c, font=font)
#     116     dx1 = secrets.randbelow(self.character_offset_dx[1] - self.character_offset_dx[0] + 1) + self.character_offset_dx[0]
#
# File ~/miniconda3/lib/python3.13/site-packages/captcha/image.py:74, in ImageCaptcha.truefonts(self)
#      71 if self._truefonts:
#      72     return self._truefonts
#      73 self._truefonts = [
# ---> 74     truetype(n, s)
#      75     for n in self._fonts
#      76     for s in self._font_sizes
#      77 ]
#      78 return self._truefonts
#
# File ~/miniconda3/lib/python3.13/site-packages/PIL/ImageFont.py:861, in truetype(font, size, index, encoding, layout_engine)
#     858     return FreeTypeFont(font, size, index, encoding, layout_engine)
#     860 try:
# --> 861     return freetype(font)
#     862 except OSError:
#     863     if not is_path(font):
#
# File ~/miniconda3/lib/python3.13/site-packages/PIL/ImageFont.py:858, in truetype.<locals>.freetype(font)
#     857 def freetype(font: StrOrBytesPath | BinaryIO) -> FreeTypeFont:
# --> 858     return FreeTypeFont(font, size, index, encoding, layout_engine)
#
# File ~/miniconda3/lib/python3.13/site-packages/PIL/ImageFont.py:274, in FreeTypeFont.__init__(self, font, size, index, encoding, layout_engine)
#     272                 load_from_bytes(f)
#     273             return
# --> 274     self.font = core.getfont(
#     275         font, size, index, encoding, layout_engine=layout_engine
#     276     )
#     277 else:
#     278     load_from_bytes(cast(IO[bytes], font))
#
# OSError: cannot open resource

# %%
character_offset_dx: tuple[int, int] = (0, 4)
character_offset_dy: tuple[int, int] = (0, 6)
character_rotate: tuple[int, int] = (-30, 30)
character_warp_dx: tuple[float, float] = (0.1, 0.3)
character_warp_dy: tuple[float, float] = (0.2, 0.3)
word_space_probability: float = 0.5
word_offset_dx: float = 0.25
